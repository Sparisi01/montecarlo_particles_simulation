# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt("output/convergence_test_file.csv", delimiter=";")

plt.plot(data[:,0],data[:,1], "o")
plt.plot(data[:,0],data[:,2])
plt.plot(data[:,0],data[:,3])
plt.plot(data[:,0],data[:,4])
